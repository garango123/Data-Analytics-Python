# %% [markdown]
# # World Population Analysis
# This notebook analyzes global population data using Python (pandas, matplotlib, seaborn).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/world_population.csv')
df.head()
